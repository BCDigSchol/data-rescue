# %%
"""Fetch indivdual IMLS resources gathered from data.gov 

This script looks for imls-gov.json within a relative data/imls/ file path.
It will parse through the json file and fetch all the listed resource files.
It then creates sub directories for each fetched resource.

Note: Code has been tested with Python 2.7.13 and untested with Python 3.x
"""

import json
import os
import errno
import re
import urllib2
import sys
import time


__author__ = "Jesse Martinez"

__maintainer__ = "Jesse Martinez"
__email__ = "jesse.martinez@bc.edu"
__status__ = "Works but use at your own risk!"

# time in seconds between getting another resource
cooldown_time = 1

# file paths
file_parent_path = "data/"
file_sub_path = "imls/"
file_path = file_parent_path + file_sub_path
file_name = "imls-gov.json"
file_location = file_path + file_name

result_harvest_url_prefix = "https://catalog.data.gov/harvest/object/"

# %%
def printOut(outfile, str):
    """utility function to print to standard out and to file"""
    print str
    if outfile:
        outfile.write("\n" + str)

# %%
def getResource(url, file_path_and_name):
    """grabs the resource and save it to local file """
    if not url or not file_path_and_name:
        return None
    
    #printOut(file_log, "URL: %s" % url)
    #printOut(file_log, "file_path_and_name: %s" % file_path_and_name)
    
    # http://stackoverflow.com/questions/1726402/in-python-how-do-i-use-urllib-to-see-if-a-website-is-404-or-200
    # TODO: use urllib.urlencode to make sure urls are encoded
    req = urllib2.Request(url)
    try:
        resp = urllib2.urlopen(req)
    except urllib2.HTTPError as e:
        if e.code == 404:
            printOut(file_log, "Received 404. Could not fild file!")
        else:
            printOut(file_log, "Received %s. Could not fild file!" % e.code)
        return None
    except urllib2.URLError as e:
        printOut(file_log, "Could not find file! Error message: %s" % e)
        return None
    else:
        # Received 200
        body = resp.read()
    try:
        with open(file_path_and_name, "wb") as local_file:
            local_file.write(body)
        local_file.close()
        file_size = os.path.getsize(file_path_and_name)
        
        # we assume the file size is greater than 0
        return file_size
    except EnvironmentError:
        printOut(file_log, "Error: Can't save file: %s" % file_path_and_name)
    
    return None

# %%
"""start of the core of this script"""

# create log file
file_time = time.strftime("%Y%m%d-%H%M%S")
#file_log_name = "log-%s.txt" % file_time
file_log_name = "log.txt"
try:
    file_log = open(file_path + file_log_name, "w")
    printOut(file_log, "Script started at %s" % file_time)
    printOut(file_log, "\nCooldown time between calls %s" % cooldown_time)
    
except IOError:
    printOut(None, "Error: Could not write to file: %s%s" % (file_path, file_log_name) )
    printOut(None, "Exiting script\n")
    sys.exit()
# Out:
# Script started at 20170418-213914
#
# Cooldown time between calls 1

# %%
# read in json file
try:
    with open(file_location) as data_file:
        data = json.load(data_file)
    printOut(file_log, "Read in file: %s" % file_location)
except EnvironmentError:
    printOut(file_log, "Error: Can't open file: %s" % file_location)
    printOut(file_log, "Exiting script")
    file_log.close()
    sys.exit()
# Out:
# Read in file: data/imls/imls-gov.json

# %%
# loop through and grab each resource from each result
for res in data["result"]["results"]:
    res_title = res["title"]
    res_title_clean = re.sub('[^0-9a-zA-Z]+', '_', res_title)
    res_name = res["name"]
    res_dir = file_path + res_name + "/"
    
    printOut(file_log, "\nFound result title: %s" % res_title)
    
    # create directory for this result
    # on fail, write to parent directory
    # TODO: check if parent directory is writable
    if not os.path.exists(res_dir):
        try:
            os.makedirs(res_dir)
            printOut(file_log, "Created directory: %s" % res_dir)
        except OSError:
            printOut(file_log, "Error: Can't create directory: %s" % res_dir)
            # at this point we'll try to write to the parent directory
            res_dir = file_path
            printOut(file_log, "Warning: Writing to parent directory instead: %s" % res_dir)
    else:
        printOut(file_log, "Found existing directory: %s" % res_dir)
    
    # check that there is an "extras" section in json file
    # exit if not found
    if "extras" not in res:
        printOut(file_log, "Could not find expected results in json file! Missing 'extras' section. Exiting")
        sys.exit()
    
    # get harvest_object_id file
    # save as data.json
    found_harvest_object_id = False
    for extra in res["extras"]:
        if "key" in extra and extra["key"] == "harvest_object_id" and not found_harvest_object_id:
            harvest_object_id_url = result_harvest_url_prefix + extra["value"]
            #print result_harvest_url + extra["value"]
            found_harvest_object_id = True
            
            download_status = "Downloading data.json ... "
            
            # get the resource
            # returns file size on success and None on failure
            resp = getResource(result_harvest_url_prefix + extra["value"], res_dir + "/data.json")
            
            if resp:
                printOut(file_log, download_status + "success! file size %s bytes" % resp)
            else:
                # this failed but we continue to the next resource
                printOut(file_log, download_status + "failed. See log file for description")
         
    
    # check that there is an "extras" section in json file
    # exit if not found
    if "resources" not in res and "resource" not in res["resources"]:
        printOut(file_log, "Could not find exprected results in json file! Missing 'resources' section. Exiting")
        sys.exit()
    
    # get each resource
    for resource in res["resources"]:
        resource_url = resource.get("url")
        resource_format = resource.get("format")
        resource_description = resource.get("description")
        
        # when in doubt, give it a txt extension
        if not resource_format:
            resource_format = ".txt"
        else:
            resource_format = "." + resource_format.lower()
        
        if not resource_url:
            printOut(file_log, "Could not find url for resource!")
            continue
        
        # check to see if there is a resource_description
        if resource_description:
            file_name_and_path = res_dir + resource_description
        else:
            file_name_and_path = res_dir + res_name + resource_format
        
        download_status = "Downloading %s as %s ... " % (resource["url"], file_name_and_path)
            
        # get the resource
        # returns file size on success and None on failure
        time.sleep(cooldown_time)
        resp = getResource(resource["url"], file_name_and_path)
        #resp = None

        if resp:
            printOut(file_log, download_status + "success! File size %s bytes" % resp)
        else:
            # this failed but we continue to the next resource
            printOut(file_log, download_status + "failed. See log file for description")
    

file_time = time.strftime("%Y%m%d-%H%M%S")
printOut(file_log, "\nScript ended at %s" % file_time)
# Out:
# Found result title: Administrative Discretionary Grants (FY 1996-2014)
# Found existing directory: data/imls/administrative-discretionary-grants-fy-1996-2014/
# Downloading data.json ... success! file size 1622 bytes
# Downloading https://data.imls.gov/api/views/kf5m-pcwv/rows.csv?accessType=DOWNLOAD as data/imls/administrative-discretionary-grants-fy-1996-2014/administrative-discretionary-grants-fy-1996-2014.csv ... success! File size 5986270 bytes
# Downloading https://data.imls.gov/api/views/kf5m-pcwv/rows.rdf?accessType=DOWNLOAD as data/imls/administrative-discretionary-grants-fy-1996-2014/administrative-discretionary-grants-fy-1996-2014.rdf ... success! File size 1006149 bytes
# Downloading https://data.imls.gov/api/views/kf5m-pcwv/rows.json?accessType=DOWNLOAD as data/imls/administrative-discretionary-grants-fy-1996-2014/administrative-discretionary-grants-fy-1996-2014.json ... success! File size 11332401 bytes
# Downloading https://data.imls.gov/api/views/kf5m-pcwv/rows.xml?accessType=DOWNLOAD as data/imls/administrative-discretionary-grants-fy-1996-2014/administrative-discretionary-grants-fy-1996-2014.xml ... success! File size 23850656 bytes
#
# Found result title: Museum Universe Data File FY 2015 Q3
# Created directory: data/imls/museum-universe-data-file-fy-2015-q3/
# Downloading data.json ... success! file size 1504 bytes
# Downloading https://data.imls.gov/api/views/ku5e-zr2b/rows.csv?accessType=DOWNLOAD as data/imls/museum-universe-data-file-fy-2015-q3/museum-universe-data-file-fy-2015-q3.csv ... success! File size 12302927 bytes
# Downloading https://data.imls.gov/api/views/ku5e-zr2b/rows.rdf?accessType=DOWNLOAD as data/imls/museum-universe-data-file-fy-2015-q3/museum-universe-data-file-fy-2015-q3.rdf ... success! File size 1119520 bytes
# Downloading https://data.imls.gov/api/views/ku5e-zr2b/rows.json?accessType=DOWNLOAD as data/imls/museum-universe-data-file-fy-2015-q3/museum-universe-data-file-fy-2015-q3.json ... success! File size 32657277 bytes
# Downloading https://data.imls.gov/api/views/ku5e-zr2b/rows.xml?accessType=DOWNLOAD as data/imls/museum-universe-data-file-fy-2015-q3/museum-universe-data-file-fy-2015-q3.xml ... success! File size 54898907 bytes
#
# Found result title: FOIA Requests (FY 2007-2015)
# Created directory: data/imls/foia-requests-fy-2007-2015/
# Downloading data.json ... success! file size 1556 bytes
# Downloading https://data.imls.gov/api/views/9dh4-qcur/rows.csv?accessType=DOWNLOAD as data/imls/foia-requests-fy-2007-2015/foia-requests-fy-2007-2015.csv ... success! File size 1583 bytes
# Downloading https://data.imls.gov/api/views/9dh4-qcur/rows.rdf?accessType=DOWNLOAD as data/imls/foia-requests-fy-2007-2015/foia-requests-fy-2007-2015.rdf ... success! File size 21616 bytes
# Downloading https://data.imls.gov/api/views/9dh4-qcur/rows.json?accessType=DOWNLOAD as data/imls/foia-requests-fy-2007-2015/foia-requests-fy-2007-2015.json ... success! File size 31350 bytes
# Downloading https://data.imls.gov/api/views/9dh4-qcur/rows.xml?accessType=DOWNLOAD as data/imls/foia-requests-fy-2007-2015/foia-requests-fy-2007-2015.xml ... success! File size 17956 bytes
#
# Found result title: FY 2008 Public Libraries Survey
# Created directory: data/imls/fy-2008-public-libraries-survey/
# Downloading data.json ... success! file size 2488 bytes
# Downloading https://www.imls.gov/sites/default/files/bridge_study_imputations_fy06-08.pdf as data/imls/fy-2008-public-libraries-survey/bridge_study_imputations_fy06-08.pdf ... success! File size 168697 bytes
# Downloading https://www.imls.gov/sites/default/files/pupld08a_sas.zip as data/imls/fy-2008-public-libraries-survey/pupld08a_sas.zip ... success! File size 3912036 bytes
# Downloading https://www.imls.gov/sites/default/files/fy2008_pls_report_usernote.pdf as data/imls/fy-2008-public-libraries-survey/fy2008_pls_report_usernote.pdf ... success! File size 7752 bytes
# Downloading https://www.imls.gov/sites/default/files/pupld08a_csv.zip as data/imls/fy-2008-public-libraries-survey/pupld08a_csv.zip ... success! File size 2958065 bytes
#
# Found result title: State Profiles: FY 2013 Public Libraries Survey
# Created directory: data/imls/state-profiles-fy-2013-public-libraries-survey/
# Downloading data.json ... success! file size 1934 bytes
# Downloading https://data.imls.gov/api/views/d859-gh7z/rows.csv?accessType=DOWNLOAD as data/imls/state-profiles-fy-2013-public-libraries-survey/state-profiles-fy-2013-public-libraries-survey.csv ... success! File size 45951 bytes
# Downloading https://data.imls.gov/api/views/d859-gh7z/rows.rdf?accessType=DOWNLOAD as data/imls/state-profiles-fy-2013-public-libraries-survey/state-profiles-fy-2013-public-libraries-survey.rdf ... success! File size 255323 bytes
# Downloading https://data.imls.gov/api/views/d859-gh7z/rows.json?accessType=DOWNLOAD as data/imls/state-profiles-fy-2013-public-libraries-survey/state-profiles-fy-2013-public-libraries-survey.json ... success! File size 203536 bytes
# Downloading https://data.imls.gov/api/views/d859-gh7z/rows.xml?accessType=DOWNLOAD as data/imls/state-profiles-fy-2013-public-libraries-survey/state-profiles-fy-2013-public-libraries-survey.xml ... success! File size 175753 bytes
#
# Found result title: Museum Universe Data File FY 2014 Q3
# Created directory: data/imls/museum-universe-data-file-fy-2014-q3/
# Downloading data.json ... success! file size 1555 bytes
# Downloading https://data.imls.gov/api/views/5rw9-2vgh/rows.csv?accessType=DOWNLOAD as data/imls/museum-universe-data-file-fy-2014-q3/museum-universe-data-file-fy-2014-q3.csv ... success! File size 12364337 bytes
# Downloading https://data.imls.gov/api/views/5rw9-2vgh/rows.rdf?accessType=DOWNLOAD as data/imls/museum-universe-data-file-fy-2014-q3/museum-universe-data-file-fy-2014-q3.rdf ... success! File size 1148799 bytes
# Downloading https://data.imls.gov/api/views/5rw9-2vgh/rows.json?accessType=DOWNLOAD as data/imls/museum-universe-data-file-fy-2014-q3/museum-universe-data-file-fy-2014-q3.json ... success! File size 25506309 bytes
# Downloading https://data.imls.gov/api/views/5rw9-2vgh/rows.xml?accessType=DOWNLOAD as data/imls/museum-universe-data-file-fy-2014-q3/museum-universe-data-file-fy-2014-q3.xml ... success! File size 60182375 bytes
#
# Found result title: State Libraries Survey, FY 1994, Part 2: SLAA-Provided Services
# Created directory: data/imls/state-libraries-survey-fy-1994-part-2-slaa-provided-services/
# Downloading data.json ... success! file size 1978 bytes
# Downloading https://data.imls.gov/api/views/k4m8-cnzp/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1994-part-2-slaa-provided-services/state-libraries-survey-fy-1994-part-2-slaa-provided-services.csv ... success! File size 22715 bytes
# Downloading https://data.imls.gov/api/views/k4m8-cnzp/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1994-part-2-slaa-provided-services/state-libraries-survey-fy-1994-part-2-slaa-provided-services.rdf ... success! File size 209270 bytes
# Downloading https://data.imls.gov/api/views/k4m8-cnzp/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1994-part-2-slaa-provided-services/state-libraries-survey-fy-1994-part-2-slaa-provided-services.json ... success! File size 119796 bytes
# Downloading https://data.imls.gov/api/views/k4m8-cnzp/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1994-part-2-slaa-provided-services/state-libraries-survey-fy-1994-part-2-slaa-provided-services.xml ... success! File size 139502 bytes
#
# Found result title: State Libraries Survey, FY 2002, Part 3: Revenue & Expenditures
# Created directory: data/imls/state-libraries-survey-fy-2002-part-3-revenue-expenditures/
# Downloading data.json ... success! file size 1979 bytes
# Downloading https://data.imls.gov/api/views/txdv-aers/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2002-part-3-revenue-expenditures/state-libraries-survey-fy-2002-part-3-revenue-expenditures.csv ... success! File size 57845 bytes
# Downloading https://data.imls.gov/api/views/txdv-aers/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2002-part-3-revenue-expenditures/state-libraries-survey-fy-2002-part-3-revenue-expenditures.rdf ... success! File size 228606 bytes
# Downloading https://data.imls.gov/api/views/txdv-aers/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2002-part-3-revenue-expenditures/state-libraries-survey-fy-2002-part-3-revenue-expenditures.json ... success! File size 221194 bytes
# Downloading https://data.imls.gov/api/views/txdv-aers/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2002-part-3-revenue-expenditures/state-libraries-survey-fy-2002-part-3-revenue-expenditures.xml ... success! File size 159409 bytes
#
# Found result title: State Libraries Survey, FY 1997, Part 3: Revenue & Expenditures
# Created directory: data/imls/state-libraries-survey-fy-1997-part-3-revenue-expenditures/
# Downloading data.json ... success! file size 1979 bytes
# Downloading https://data.imls.gov/api/views/xzhn-73j5/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1997-part-3-revenue-expenditures/state-libraries-survey-fy-1997-part-3-revenue-expenditures.csv ... success! File size 58631 bytes
# Downloading https://data.imls.gov/api/views/xzhn-73j5/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1997-part-3-revenue-expenditures/state-libraries-survey-fy-1997-part-3-revenue-expenditures.rdf ... success! File size 226880 bytes
# Downloading https://data.imls.gov/api/views/xzhn-73j5/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1997-part-3-revenue-expenditures/state-libraries-survey-fy-1997-part-3-revenue-expenditures.json ... success! File size 224592 bytes
# Downloading https://data.imls.gov/api/views/xzhn-73j5/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1997-part-3-revenue-expenditures/state-libraries-survey-fy-1997-part-3-revenue-expenditures.xml ... success! File size 158509 bytes
#
# Found result title: State Libraries Survey, FY 2010, Part 1: Operations & Workforce
# Created directory: data/imls/state-libraries-survey-fy-2010-part-1-operations-workforce/
# Downloading data.json ... success! file size 1979 bytes
# Downloading https://data.imls.gov/api/views/cjfg-5pz8/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2010-part-1-operations-workforce/state-libraries-survey-fy-2010-part-1-operations-workforce.csv ... success! File size 29689 bytes
# Downloading https://data.imls.gov/api/views/cjfg-5pz8/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2010-part-1-operations-workforce/state-libraries-survey-fy-2010-part-1-operations-workforce.rdf ... success! File size 240074 bytes
# Downloading https://data.imls.gov/api/views/cjfg-5pz8/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2010-part-1-operations-workforce/state-libraries-survey-fy-2010-part-1-operations-workforce.json ... success! File size 186766 bytes
# Downloading https://data.imls.gov/api/views/cjfg-5pz8/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2010-part-1-operations-workforce/state-libraries-survey-fy-2010-part-1-operations-workforce.xml ... success! File size 161949 bytes
#
# Found result title: State Libraries Survey, FY 2005, Part 2: SLAA-Provided Services
# Created directory: data/imls/state-libraries-survey-fy-2005-part-2-slaa-provided-services/
# Downloading data.json ... success! file size 1978 bytes
# Downloading https://data.imls.gov/api/views/9uhv-6je7/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2005-part-2-slaa-provided-services/state-libraries-survey-fy-2005-part-2-slaa-provided-services.csv ... success! File size 25881 bytes
# Downloading https://data.imls.gov/api/views/9uhv-6je7/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2005-part-2-slaa-provided-services/state-libraries-survey-fy-2005-part-2-slaa-provided-services.rdf ... success! File size 239289 bytes
# Downloading https://data.imls.gov/api/views/9uhv-6je7/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2005-part-2-slaa-provided-services/state-libraries-survey-fy-2005-part-2-slaa-provided-services.json ... success! File size 141966 bytes
# Downloading https://data.imls.gov/api/views/9uhv-6je7/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2005-part-2-slaa-provided-services/state-libraries-survey-fy-2005-part-2-slaa-provided-services.xml ... success! File size 159327 bytes
#
# Found result title: Main Libraries, Branches, and Bookmobiles: FY 2014 Public Libraries Survey (Outlet Data)
# Created directory: data/imls/main-libraries-branches-and-bookmobiles-fy-2014-public-libraries-survey-outlet-data/
# Downloading data.json ... success! file size 2072 bytes
# Downloading https://data.imls.gov/api/views/ucdn-7aur/rows.csv?accessType=DOWNLOAD as data/imls/main-libraries-branches-and-bookmobiles-fy-2014-public-libraries-survey-outlet-data/main-libraries-branches-and-bookmobiles-fy-2014-public-libraries-survey-outlet-data.csv ... success! File size 2883531 bytes
# Downloading https://data.imls.gov/api/views/ucdn-7aur/rows.rdf?accessType=DOWNLOAD as data/imls/main-libraries-branches-and-bookmobiles-fy-2014-public-libraries-survey-outlet-data/main-libraries-branches-and-bookmobiles-fy-2014-public-libraries-survey-outlet-data.rdf ... success! File size 629250 bytes
# Downloading https://data.imls.gov/api/views/ucdn-7aur/rows.json?accessType=DOWNLOAD as data/imls/main-libraries-branches-and-bookmobiles-fy-2014-public-libraries-survey-outlet-data/main-libraries-branches-and-bookmobiles-fy-2014-public-libraries-survey-outlet-data.json ... success! File size 7106641 bytes
# Downloading https://data.imls.gov/api/views/ucdn-7aur/rows.xml?accessType=DOWNLOAD as data/imls/main-libraries-branches-and-bookmobiles-fy-2014-public-libraries-survey-outlet-data/main-libraries-branches-and-bookmobiles-fy-2014-public-libraries-survey-outlet-data.xml ... success! File size 15795363 bytes
#
# Found result title: Library Systems: FY 2014 Public Libraries Survey (Administrative Entity Data)
# Created directory: data/imls/library-systems-fy-2014-public-libraries-survey-administrative-entity-data/
# Downloading data.json ... success! file size 2003 bytes
# Downloading https://data.imls.gov/api/views/wzfa-2gdc/rows.csv?accessType=DOWNLOAD as data/imls/library-systems-fy-2014-public-libraries-survey-administrative-entity-data/library-systems-fy-2014-public-libraries-survey-administrative-entity-data.csv ... success! File size 4605826 bytes
# Downloading https://data.imls.gov/api/views/wzfa-2gdc/rows.rdf?accessType=DOWNLOAD as data/imls/library-systems-fy-2014-public-libraries-survey-administrative-entity-data/library-systems-fy-2014-public-libraries-survey-administrative-entity-data.rdf ... success! File size 2224249 bytes
# Downloading https://data.imls.gov/api/views/wzfa-2gdc/rows.json?accessType=DOWNLOAD as data/imls/library-systems-fy-2014-public-libraries-survey-administrative-entity-data/library-systems-fy-2014-public-libraries-survey-administrative-entity-data.json ... success! File size 9317723 bytes
# Downloading https://data.imls.gov/api/views/wzfa-2gdc/rows.xml?accessType=DOWNLOAD as data/imls/library-systems-fy-2014-public-libraries-survey-administrative-entity-data/library-systems-fy-2014-public-libraries-survey-administrative-entity-data.xml ... success! File size 31762005 bytes
#
# Found result title: State Libraries Survey, FY 2003, Part 2: SLAA-Provided Services
# Created directory: data/imls/state-libraries-survey-fy-2003-part-2-slaa-provided-services/
# Downloading data.json ... success! file size 1978 bytes
# Downloading https://data.imls.gov/api/views/4rgs-bhcf/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2003-part-2-slaa-provided-services/state-libraries-survey-fy-2003-part-2-slaa-provided-services.csv ... success! File size 24586 bytes
# Downloading https://data.imls.gov/api/views/4rgs-bhcf/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2003-part-2-slaa-provided-services/state-libraries-survey-fy-2003-part-2-slaa-provided-services.rdf ... success! File size 223461 bytes
# Downloading https://data.imls.gov/api/views/4rgs-bhcf/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2003-part-2-slaa-provided-services/state-libraries-survey-fy-2003-part-2-slaa-provided-services.json ... success! File size 133151 bytes
# Downloading https://data.imls.gov/api/views/4rgs-bhcf/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2003-part-2-slaa-provided-services/state-libraries-survey-fy-2003-part-2-slaa-provided-services.xml ... success! File size 149109 bytes
#
# Found result title: State Libraries Survey, FY 2012, Part 3: Revenue & Expenditures
# Created directory: data/imls/state-libraries-survey-fy-2012-part-3-revenue-expenditures/
# Downloading data.json ... success! file size 1979 bytes
# Downloading https://data.imls.gov/api/views/9j5w-shf3/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2012-part-3-revenue-expenditures/state-libraries-survey-fy-2012-part-3-revenue-expenditures.csv ... success! File size 57700 bytes
# Downloading https://data.imls.gov/api/views/9j5w-shf3/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2012-part-3-revenue-expenditures/state-libraries-survey-fy-2012-part-3-revenue-expenditures.rdf ... success! File size 213412 bytes
# Downloading https://data.imls.gov/api/views/9j5w-shf3/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2012-part-3-revenue-expenditures/state-libraries-survey-fy-2012-part-3-revenue-expenditures.json ... success! File size 203200 bytes
# Downloading https://data.imls.gov/api/views/9j5w-shf3/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2012-part-3-revenue-expenditures/state-libraries-survey-fy-2012-part-3-revenue-expenditures.xml ... success! File size 146364 bytes
#
# Found result title: State Libraries Survey, FY 2012, Part 2: SLAA-Provided Services
# Created directory: data/imls/state-libraries-survey-fy-2012-part-2-slaa-provided-services/
# Downloading data.json ... success! file size 1978 bytes
# Downloading https://data.imls.gov/api/views/2uvr-b69k/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2012-part-2-slaa-provided-services/state-libraries-survey-fy-2012-part-2-slaa-provided-services.csv ... success! File size 26145 bytes
# Downloading https://data.imls.gov/api/views/2uvr-b69k/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2012-part-2-slaa-provided-services/state-libraries-survey-fy-2012-part-2-slaa-provided-services.rdf ... success! File size 239241 bytes
# Downloading https://data.imls.gov/api/views/2uvr-b69k/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2012-part-2-slaa-provided-services/state-libraries-survey-fy-2012-part-2-slaa-provided-services.json ... success! File size 141799 bytes
# Downloading https://data.imls.gov/api/views/2uvr-b69k/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2012-part-2-slaa-provided-services/state-libraries-survey-fy-2012-part-2-slaa-provided-services.xml ... success! File size 159279 bytes
#
# Found result title: Library Systems: FY 1992-2012 Public Libraries Survey Trends (Administrative Entity)
# Created directory: data/imls/library-systems-fy-1992-2012-public-libraries-survey-trends-administrative-entity/
# Downloading data.json ... success! file size 2054 bytes
# Downloading https://data.imls.gov/api/views/uzd7-qfwt/rows.csv?accessType=DOWNLOAD as data/imls/library-systems-fy-1992-2012-public-libraries-survey-trends-administrative-entity/library-systems-fy-1992-2012-public-libraries-survey-trends-administrative-entity.csv ... success! File size 80598821 bytes
# Downloading https://data.imls.gov/api/views/uzd7-qfwt/rows.rdf?accessType=DOWNLOAD as data/imls/library-systems-fy-1992-2012-public-libraries-survey-trends-administrative-entity/library-systems-fy-1992-2012-public-libraries-survey-trends-administrative-entity.rdf ... success! File size 831686 bytes
# Downloading https://data.imls.gov/api/views/uzd7-qfwt/rows.json?accessType=DOWNLOAD as data/imls/library-systems-fy-1992-2012-public-libraries-survey-trends-administrative-entity/library-systems-fy-1992-2012-public-libraries-survey-trends-administrative-entity.json ... success! File size 231338106 bytes
# Downloading https://data.imls.gov/api/views/uzd7-qfwt/rows.xml?accessType=DOWNLOAD as data/imls/library-systems-fy-1992-2012-public-libraries-survey-trends-administrative-entity/library-systems-fy-1992-2012-public-libraries-survey-trends-administrative-entity.xml ... success! File size 311313693 bytes
#
# Found result title: Main Libraries, Branches, and Bookmobiles: FY 2012 Public Libraries Survey (Outlet)
# Created directory: data/imls/main-libraries-branches-and-bookmobiles-fy-2012-public-libraries-survey-outlet/
# Downloading data.json ... success! file size 2049 bytes
# Downloading https://data.imls.gov/api/views/ewqs-tfck/rows.csv?accessType=DOWNLOAD as data/imls/main-libraries-branches-and-bookmobiles-fy-2012-public-libraries-survey-outlet/main-libraries-branches-and-bookmobiles-fy-2012-public-libraries-survey-outlet.csv ... success! File size 3957626 bytes
# Downloading https://data.imls.gov/api/views/ewqs-tfck/rows.rdf?accessType=DOWNLOAD as data/imls/main-libraries-branches-and-bookmobiles-fy-2012-public-libraries-survey-outlet/main-libraries-branches-and-bookmobiles-fy-2012-public-libraries-survey-outlet.rdf ... success! File size 778056 bytes
# Downloading https://data.imls.gov/api/views/ewqs-tfck/rows.json?accessType=DOWNLOAD as data/imls/main-libraries-branches-and-bookmobiles-fy-2012-public-libraries-survey-outlet/main-libraries-branches-and-bookmobiles-fy-2012-public-libraries-survey-outlet.json ... success! File size 8881462 bytes
# Downloading https://data.imls.gov/api/views/ewqs-tfck/rows.xml?accessType=DOWNLOAD as data/imls/main-libraries-branches-and-bookmobiles-fy-2012-public-libraries-survey-outlet/main-libraries-branches-and-bookmobiles-fy-2012-public-libraries-survey-outlet.xml ... success! File size 18573255 bytes
#
# Found result title: State Libraries Survey, FY 2000, Part 3: Revenue & Expenditures
# Created directory: data/imls/state-libraries-survey-fy-2000-part-3-revenue-expenditures/
# Downloading data.json ... success! file size 1979 bytes
# Downloading https://data.imls.gov/api/views/jwf5-pnss/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2000-part-3-revenue-expenditures/state-libraries-survey-fy-2000-part-3-revenue-expenditures.csv ... success! File size 56941 bytes
# Downloading https://data.imls.gov/api/views/jwf5-pnss/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2000-part-3-revenue-expenditures/state-libraries-survey-fy-2000-part-3-revenue-expenditures.rdf ... success! File size 218810 bytes
# Downloading https://data.imls.gov/api/views/jwf5-pnss/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2000-part-3-revenue-expenditures/state-libraries-survey-fy-2000-part-3-revenue-expenditures.json ... success! File size 219525 bytes
# Downloading https://data.imls.gov/api/views/jwf5-pnss/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2000-part-3-revenue-expenditures/state-libraries-survey-fy-2000-part-3-revenue-expenditures.xml ... success! File size 153090 bytes
#
# Found result title: State Libraries Survey, FY 2003, Part 3: Revenue & Expenditures
# Created directory: data/imls/state-libraries-survey-fy-2003-part-3-revenue-expenditures/
# Downloading data.json ... success! file size 1979 bytes
# Downloading https://data.imls.gov/api/views/bvhh-ix9q/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2003-part-3-revenue-expenditures/state-libraries-survey-fy-2003-part-3-revenue-expenditures.csv ... success! File size 58190 bytes
# Downloading https://data.imls.gov/api/views/bvhh-ix9q/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2003-part-3-revenue-expenditures/state-libraries-survey-fy-2003-part-3-revenue-expenditures.rdf ... success! File size 231767 bytes
# Downloading https://data.imls.gov/api/views/bvhh-ix9q/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2003-part-3-revenue-expenditures/state-libraries-survey-fy-2003-part-3-revenue-expenditures.json ... success! File size 223322 bytes
# Downloading https://data.imls.gov/api/views/bvhh-ix9q/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2003-part-3-revenue-expenditures/state-libraries-survey-fy-2003-part-3-revenue-expenditures.xml ... success! File size 161496 bytes
#
# Found result title: State Libraries Survey, FY 1999, Part 2: SLAA-Provided Services
# Created directory: data/imls/state-libraries-survey-fy-1999-part-2-slaa-provided-services/
# Downloading data.json ... success! file size 1978 bytes
# Downloading https://data.imls.gov/api/views/ftxf-ex85/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1999-part-2-slaa-provided-services/state-libraries-survey-fy-1999-part-2-slaa-provided-services.csv ... success! File size 24394 bytes
# Downloading https://data.imls.gov/api/views/ftxf-ex85/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1999-part-2-slaa-provided-services/state-libraries-survey-fy-1999-part-2-slaa-provided-services.rdf ... success! File size 220228 bytes
# Downloading https://data.imls.gov/api/views/ftxf-ex85/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1999-part-2-slaa-provided-services/state-libraries-survey-fy-1999-part-2-slaa-provided-services.json ... success! File size 126823 bytes
# Downloading https://data.imls.gov/api/views/ftxf-ex85/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1999-part-2-slaa-provided-services/state-libraries-survey-fy-1999-part-2-slaa-provided-services.xml ... success! File size 147050 bytes
#
# Found result title: State Libraries Survey, FY 2012, Part 1: Operations & Workforce
# Created directory: data/imls/state-libraries-survey-fy-2012-part-1-operations-workforce/
# Downloading data.json ... success! file size 1979 bytes
# Downloading https://data.imls.gov/api/views/2sms-kv74/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2012-part-1-operations-workforce/state-libraries-survey-fy-2012-part-1-operations-workforce.csv ... success! File size 30248 bytes
# Downloading https://data.imls.gov/api/views/2sms-kv74/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2012-part-1-operations-workforce/state-libraries-survey-fy-2012-part-1-operations-workforce.rdf ... success! File size 235926 bytes
# Downloading https://data.imls.gov/api/views/2sms-kv74/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2012-part-1-operations-workforce/state-libraries-survey-fy-2012-part-1-operations-workforce.json ... success! File size 181498 bytes
# Downloading https://data.imls.gov/api/views/2sms-kv74/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2012-part-1-operations-workforce/state-libraries-survey-fy-2012-part-1-operations-workforce.xml ... success! File size 157647 bytes
#
# Found result title: State Libraries Survey, FY 2000, Part 2: SLAA-Provided Services
# Created directory: data/imls/state-libraries-survey-fy-2000-part-2-slaa-provided-services/
# Downloading data.json ... success! file size 1978 bytes
# Downloading https://data.imls.gov/api/views/pmbv-fac9/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2000-part-2-slaa-provided-services/state-libraries-survey-fy-2000-part-2-slaa-provided-services.csv ... success! File size 24401 bytes
# Downloading https://data.imls.gov/api/views/pmbv-fac9/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2000-part-2-slaa-provided-services/state-libraries-survey-fy-2000-part-2-slaa-provided-services.rdf ... success! File size 220235 bytes
# Downloading https://data.imls.gov/api/views/pmbv-fac9/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2000-part-2-slaa-provided-services/state-libraries-survey-fy-2000-part-2-slaa-provided-services.json ... success! File size 126764 bytes
# Downloading https://data.imls.gov/api/views/pmbv-fac9/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2000-part-2-slaa-provided-services/state-libraries-survey-fy-2000-part-2-slaa-provided-services.xml ... success! File size 147057 bytes
#
# Found result title: State Libraries Survey, FY 2009, Part 3: Revenue & Expenditures
# Created directory: data/imls/state-libraries-survey-fy-2009-part-3-revenue-expenditures/
# Downloading data.json ... success! file size 1979 bytes
# Downloading https://data.imls.gov/api/views/auqm-gett/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2009-part-3-revenue-expenditures/state-libraries-survey-fy-2009-part-3-revenue-expenditures.csv ... success! File size 56861 bytes
# Downloading https://data.imls.gov/api/views/auqm-gett/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2009-part-3-revenue-expenditures/state-libraries-survey-fy-2009-part-3-revenue-expenditures.rdf ... success! File size 221488 bytes
# Downloading https://data.imls.gov/api/views/auqm-gett/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2009-part-3-revenue-expenditures/state-libraries-survey-fy-2009-part-3-revenue-expenditures.json ... success! File size 213561 bytes
# Downloading https://data.imls.gov/api/views/auqm-gett/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2009-part-3-revenue-expenditures/state-libraries-survey-fy-2009-part-3-revenue-expenditures.xml ... success! File size 154583 bytes
#
# Found result title: State Libraries Survey, FY 1999, Part 3: Revenue & Expenditures
# Created directory: data/imls/state-libraries-survey-fy-1999-part-3-revenue-expenditures/
# Downloading data.json ... success! file size 1979 bytes
# Downloading https://data.imls.gov/api/views/i95s-tzua/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1999-part-3-revenue-expenditures/state-libraries-survey-fy-1999-part-3-revenue-expenditures.csv ... success! File size 57118 bytes
# Downloading https://data.imls.gov/api/views/i95s-tzua/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1999-part-3-revenue-expenditures/state-libraries-survey-fy-1999-part-3-revenue-expenditures.rdf ... success! File size 218969 bytes
# Downloading https://data.imls.gov/api/views/i95s-tzua/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1999-part-3-revenue-expenditures/state-libraries-survey-fy-1999-part-3-revenue-expenditures.json ... success! File size 220883 bytes
# Downloading https://data.imls.gov/api/views/i95s-tzua/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1999-part-3-revenue-expenditures/state-libraries-survey-fy-1999-part-3-revenue-expenditures.xml ... success! File size 153249 bytes
#
# Found result title: State Libraries Survey, FY 2006, Part 1: Operations & Workforce
# Created directory: data/imls/state-libraries-survey-fy-2006-part-1-operations-workforce/
# Downloading data.json ... success! file size 1979 bytes
# Downloading https://data.imls.gov/api/views/n7fh-zan2/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2006-part-1-operations-workforce/state-libraries-survey-fy-2006-part-1-operations-workforce.csv ... success! File size 27818 bytes
# Downloading https://data.imls.gov/api/views/n7fh-zan2/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2006-part-1-operations-workforce/state-libraries-survey-fy-2006-part-1-operations-workforce.rdf ... success! File size 217494 bytes
# Downloading https://data.imls.gov/api/views/n7fh-zan2/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2006-part-1-operations-workforce/state-libraries-survey-fy-2006-part-1-operations-workforce.json ... success! File size 160833 bytes
# Downloading https://data.imls.gov/api/views/n7fh-zan2/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2006-part-1-operations-workforce/state-libraries-survey-fy-2006-part-1-operations-workforce.xml ... success! File size 146662 bytes
#
# Found result title: Library Systems: FY 2012 Public Libraries Survey (Administrative Entity)
# Created directory: data/imls/library-systems-fy-2012-public-libraries-survey-administrative-entity/
# Downloading data.json ... success! file size 1998 bytes
# Downloading https://data.imls.gov/api/views/9fbc-csi5/rows.csv?accessType=DOWNLOAD as data/imls/library-systems-fy-2012-public-libraries-survey-administrative-entity/library-systems-fy-2012-public-libraries-survey-administrative-entity.csv ... success! File size 7454015 bytes
# Downloading https://data.imls.gov/api/views/9fbc-csi5/rows.rdf?accessType=DOWNLOAD as data/imls/library-systems-fy-2012-public-libraries-survey-administrative-entity/library-systems-fy-2012-public-libraries-survey-administrative-entity.rdf ... success! File size 2771238 bytes
# Downloading https://data.imls.gov/api/views/9fbc-csi5/rows.json?accessType=DOWNLOAD as data/imls/library-systems-fy-2012-public-libraries-survey-administrative-entity/library-systems-fy-2012-public-libraries-survey-administrative-entity.json ... success! File size 13438518 bytes
# Downloading https://data.imls.gov/api/views/9fbc-csi5/rows.xml?accessType=DOWNLOAD as data/imls/library-systems-fy-2012-public-libraries-survey-administrative-entity/library-systems-fy-2012-public-libraries-survey-administrative-entity.xml ... success! File size 35239655 bytes
#
# Found result title: State Libraries Survey, FY 1994, Part 1: Operations & Workforce
# Created directory: data/imls/state-libraries-survey-fy-1994-part-1-operations-workforce/
# Downloading data.json ... success! file size 1979 bytes
# Downloading https://data.imls.gov/api/views/b5vx-qky6/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1994-part-1-operations-workforce/state-libraries-survey-fy-1994-part-1-operations-workforce.csv ... success! File size 39397 bytes
# Downloading https://data.imls.gov/api/views/b5vx-qky6/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1994-part-1-operations-workforce/state-libraries-survey-fy-1994-part-1-operations-workforce.rdf ... success! File size 327628 bytes
# Downloading https://data.imls.gov/api/views/b5vx-qky6/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1994-part-1-operations-workforce/state-libraries-survey-fy-1994-part-1-operations-workforce.json ... success! File size 303715 bytes
# Downloading https://data.imls.gov/api/views/b5vx-qky6/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1994-part-1-operations-workforce/state-libraries-survey-fy-1994-part-1-operations-workforce.xml ... success! File size 220879 bytes
#
# Found result title: State Libraries Survey, FY 1997, Part 1: Operations & Workforce
# Created directory: data/imls/state-libraries-survey-fy-1997-part-1-operations-workforce/
# Downloading data.json ... success! file size 1979 bytes
# Downloading https://data.imls.gov/api/views/97tr-cf5g/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1997-part-1-operations-workforce/state-libraries-survey-fy-1997-part-1-operations-workforce.csv ... success! File size 37323 bytes
# Downloading https://data.imls.gov/api/views/97tr-cf5g/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1997-part-1-operations-workforce/state-libraries-survey-fy-1997-part-1-operations-workforce.rdf ... success! File size 309478 bytes
# Downloading https://data.imls.gov/api/views/97tr-cf5g/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1997-part-1-operations-workforce/state-libraries-survey-fy-1997-part-1-operations-workforce.json ... success! File size 292776 bytes
# Downloading https://data.imls.gov/api/views/97tr-cf5g/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1997-part-1-operations-workforce/state-libraries-survey-fy-1997-part-1-operations-workforce.xml ... success! File size 208966 bytes
#
# Found result title: State Libraries Survey, FY 2003, Part 1: Operations & Workforce
# Created directory: data/imls/state-libraries-survey-fy-2003-part-1-operations-workforce/
# Downloading data.json ... success! file size 1979 bytes
# Downloading https://data.imls.gov/api/views/q2nk-htvf/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2003-part-1-operations-workforce/state-libraries-survey-fy-2003-part-1-operations-workforce.csv ... success! File size 42875 bytes
# Downloading https://data.imls.gov/api/views/q2nk-htvf/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2003-part-1-operations-workforce/state-libraries-survey-fy-2003-part-1-operations-workforce.rdf ... success! File size 368515 bytes
# Downloading https://data.imls.gov/api/views/q2nk-htvf/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2003-part-1-operations-workforce/state-libraries-survey-fy-2003-part-1-operations-workforce.json ... success! File size 329085 bytes
# Downloading https://data.imls.gov/api/views/q2nk-htvf/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2003-part-1-operations-workforce/state-libraries-survey-fy-2003-part-1-operations-workforce.xml ... success! File size 248876 bytes
#
# Found result title: State Libraries Survey, FY 2004, Part 1: Operations & Workforce
# Created directory: data/imls/state-libraries-survey-fy-2004-part-1-operations-workforce/
# Downloading data.json ... success! file size 1979 bytes
# Downloading https://data.imls.gov/api/views/c4gq-ae2a/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2004-part-1-operations-workforce/state-libraries-survey-fy-2004-part-1-operations-workforce.csv ... success! File size 41770 bytes
# Downloading https://data.imls.gov/api/views/c4gq-ae2a/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2004-part-1-operations-workforce/state-libraries-survey-fy-2004-part-1-operations-workforce.rdf ... success! File size 361746 bytes
# Downloading https://data.imls.gov/api/views/c4gq-ae2a/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2004-part-1-operations-workforce/state-libraries-survey-fy-2004-part-1-operations-workforce.json ... success! File size 321106 bytes
# Downloading https://data.imls.gov/api/views/c4gq-ae2a/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2004-part-1-operations-workforce/state-libraries-survey-fy-2004-part-1-operations-workforce.xml ... success! File size 244351 bytes
#
# Found result title: State Libraries Survey, FY 2002, Part 1: Operations & Workforce
# Created directory: data/imls/state-libraries-survey-fy-2002-part-1-operations-workforce/
# Downloading data.json ... success! file size 1979 bytes
# Downloading https://data.imls.gov/api/views/vsm8-pjjt/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2002-part-1-operations-workforce/state-libraries-survey-fy-2002-part-1-operations-workforce.csv ... success! File size 42767 bytes
# Downloading https://data.imls.gov/api/views/vsm8-pjjt/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2002-part-1-operations-workforce/state-libraries-survey-fy-2002-part-1-operations-workforce.rdf ... success! File size 365661 bytes
# Downloading https://data.imls.gov/api/views/vsm8-pjjt/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2002-part-1-operations-workforce/state-libraries-survey-fy-2002-part-1-operations-workforce.json ... success! File size 325761 bytes
# Downloading https://data.imls.gov/api/views/vsm8-pjjt/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2002-part-1-operations-workforce/state-libraries-survey-fy-2002-part-1-operations-workforce.xml ... success! File size 247096 bytes
#
# Found result title: State Libraries Survey, FY 2002, Part 2: SLAA-Provided Services
# Created directory: data/imls/state-libraries-survey-fy-2002-part-2-slaa-provided-services/
# Downloading data.json ... success! file size 1978 bytes
# Downloading https://data.imls.gov/api/views/56wb-gfbm/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2002-part-2-slaa-provided-services/state-libraries-survey-fy-2002-part-2-slaa-provided-services.csv ... success! File size 24379 bytes
# Downloading https://data.imls.gov/api/views/56wb-gfbm/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2002-part-2-slaa-provided-services/state-libraries-survey-fy-2002-part-2-slaa-provided-services.rdf ... success! File size 220420 bytes
# Downloading https://data.imls.gov/api/views/56wb-gfbm/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2002-part-2-slaa-provided-services/state-libraries-survey-fy-2002-part-2-slaa-provided-services.json ... success! File size 131774 bytes
# Downloading https://data.imls.gov/api/views/56wb-gfbm/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2002-part-2-slaa-provided-services/state-libraries-survey-fy-2002-part-2-slaa-provided-services.xml ... success! File size 147142 bytes
#
# Found result title: State Libraries Survey, FY 2001, Part 2: SLAA-Provided Services
# Created directory: data/imls/state-libraries-survey-fy-2001-part-2-slaa-provided-services/
# Downloading data.json ... success! file size 1978 bytes
# Downloading https://data.imls.gov/api/views/ripw-z3s3/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2001-part-2-slaa-provided-services/state-libraries-survey-fy-2001-part-2-slaa-provided-services.csv ... success! File size 24415 bytes
# Downloading https://data.imls.gov/api/views/ripw-z3s3/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2001-part-2-slaa-provided-services/state-libraries-survey-fy-2001-part-2-slaa-provided-services.rdf ... success! File size 220251 bytes
# Downloading https://data.imls.gov/api/views/ripw-z3s3/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2001-part-2-slaa-provided-services/state-libraries-survey-fy-2001-part-2-slaa-provided-services.json ... success! File size 126790 bytes
# Downloading https://data.imls.gov/api/views/ripw-z3s3/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2001-part-2-slaa-provided-services/state-libraries-survey-fy-2001-part-2-slaa-provided-services.xml ... success! File size 147076 bytes
#
# Found result title: State Libraries Survey, FY 1997, Part 2: SLAA-Provided Services
# Created directory: data/imls/state-libraries-survey-fy-1997-part-2-slaa-provided-services/
# Downloading data.json ... success! file size 1978 bytes
# Downloading https://data.imls.gov/api/views/b2z7-ns9b/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1997-part-2-slaa-provided-services/state-libraries-survey-fy-1997-part-2-slaa-provided-services.csv ... success! File size 22763 bytes
# Downloading https://data.imls.gov/api/views/b2z7-ns9b/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1997-part-2-slaa-provided-services/state-libraries-survey-fy-1997-part-2-slaa-provided-services.rdf ... success! File size 209376 bytes
# Downloading https://data.imls.gov/api/views/b2z7-ns9b/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1997-part-2-slaa-provided-services/state-libraries-survey-fy-1997-part-2-slaa-provided-services.json ... success! File size 120256 bytes
# Downloading https://data.imls.gov/api/views/b2z7-ns9b/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1997-part-2-slaa-provided-services/state-libraries-survey-fy-1997-part-2-slaa-provided-services.xml ... success! File size 139586 bytes
#
# Found result title: State Libraries Survey, FY 2001, Part 1: Operations & Workforce
# Created directory: data/imls/state-libraries-survey-fy-2001-part-1-operations-workforce/
# Downloading data.json ... success! file size 1979 bytes
# Downloading https://data.imls.gov/api/views/qxka-nndr/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2001-part-1-operations-workforce/state-libraries-survey-fy-2001-part-1-operations-workforce.csv ... success! File size 42565 bytes
# Downloading https://data.imls.gov/api/views/qxka-nndr/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2001-part-1-operations-workforce/state-libraries-survey-fy-2001-part-1-operations-workforce.rdf ... success! File size 355451 bytes
# Downloading https://data.imls.gov/api/views/qxka-nndr/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2001-part-1-operations-workforce/state-libraries-survey-fy-2001-part-1-operations-workforce.json ... success! File size 325265 bytes
# Downloading https://data.imls.gov/api/views/qxka-nndr/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2001-part-1-operations-workforce/state-libraries-survey-fy-2001-part-1-operations-workforce.xml ... success! File size 240256 bytes
#
# Found result title: State Libraries Survey, FY 2007, Part 3: Revenue & Expenditures
# Created directory: data/imls/state-libraries-survey-fy-2007-part-3-revenue-expenditures/
# Downloading data.json ... success! file size 1979 bytes
# Downloading https://data.imls.gov/api/views/9wry-mtm5/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2007-part-3-revenue-expenditures/state-libraries-survey-fy-2007-part-3-revenue-expenditures.csv ... success! File size 56716 bytes
# Downloading https://data.imls.gov/api/views/9wry-mtm5/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2007-part-3-revenue-expenditures/state-libraries-survey-fy-2007-part-3-revenue-expenditures.rdf ... success! File size 221550 bytes
# Downloading https://data.imls.gov/api/views/9wry-mtm5/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2007-part-3-revenue-expenditures/state-libraries-survey-fy-2007-part-3-revenue-expenditures.json ... success! File size 213360 bytes
# Downloading https://data.imls.gov/api/views/9wry-mtm5/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2007-part-3-revenue-expenditures/state-libraries-survey-fy-2007-part-3-revenue-expenditures.xml ... success! File size 154491 bytes
#
# Found result title: State Libraries Survey, FY 2007, Part 2: SLAA-Provided Services
# Created directory: data/imls/state-libraries-survey-fy-2007-part-2-slaa-provided-services/
# Downloading data.json ... success! file size 1978 bytes
# Downloading https://data.imls.gov/api/views/f7vn-xa5f/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2007-part-2-slaa-provided-services/state-libraries-survey-fy-2007-part-2-slaa-provided-services.csv ... success! File size 25929 bytes
# Downloading https://data.imls.gov/api/views/f7vn-xa5f/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2007-part-2-slaa-provided-services/state-libraries-survey-fy-2007-part-2-slaa-provided-services.rdf ... success! File size 239132 bytes
# Downloading https://data.imls.gov/api/views/f7vn-xa5f/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2007-part-2-slaa-provided-services/state-libraries-survey-fy-2007-part-2-slaa-provided-services.json ... success! File size 141963 bytes
# Downloading https://data.imls.gov/api/views/f7vn-xa5f/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2007-part-2-slaa-provided-services/state-libraries-survey-fy-2007-part-2-slaa-provided-services.xml ... success! File size 159324 bytes
#
# Found result title: State Libraries Survey, FY 2008, Part 2: SLAA-Provided Services
# Created directory: data/imls/state-libraries-survey-fy-2008-part-2-slaa-provided-services/
# Downloading data.json ... success! file size 1978 bytes
# Downloading https://data.imls.gov/api/views/y3er-bkmc/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2008-part-2-slaa-provided-services/state-libraries-survey-fy-2008-part-2-slaa-provided-services.csv ... success! File size 25878 bytes
# Downloading https://data.imls.gov/api/views/y3er-bkmc/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2008-part-2-slaa-provided-services/state-libraries-survey-fy-2008-part-2-slaa-provided-services.rdf ... success! File size 239081 bytes
# ...
# Created directory: data/imls/state-libraries-survey-fy-2005-part-1-operations-workforce/
# Downloading data.json ... success! file size 1979 bytes
# Downloading https://data.imls.gov/api/views/vbzm-6ydx/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2005-part-1-operations-workforce/state-libraries-survey-fy-2005-part-1-operations-workforce.csv ... success! File size 27859 bytes
# Downloading https://data.imls.gov/api/views/vbzm-6ydx/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2005-part-1-operations-workforce/state-libraries-survey-fy-2005-part-1-operations-workforce.rdf ... success! File size 217535 bytes
# Downloading https://data.imls.gov/api/views/vbzm-6ydx/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2005-part-1-operations-workforce/state-libraries-survey-fy-2005-part-1-operations-workforce.json ... success! File size 161573 bytes
# Downloading https://data.imls.gov/api/views/vbzm-6ydx/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2005-part-1-operations-workforce/state-libraries-survey-fy-2005-part-1-operations-workforce.xml ... success! File size 146703 bytes
#
# Found result title: State Libraries Survey, FY 1998, Part 1: Operations & Workforce
# Created directory: data/imls/state-libraries-survey-fy-1998-part-1-operations-workforce/
# Downloading data.json ... success! file size 1979 bytes
# Downloading https://data.imls.gov/api/views/ne6m-kay3/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1998-part-1-operations-workforce/state-libraries-survey-fy-1998-part-1-operations-workforce.csv ... success! File size 41112 bytes
# Downloading https://data.imls.gov/api/views/ne6m-kay3/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1998-part-1-operations-workforce/state-libraries-survey-fy-1998-part-1-operations-workforce.rdf ... success! File size 340045 bytes
# Downloading https://data.imls.gov/api/views/ne6m-kay3/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1998-part-1-operations-workforce/state-libraries-survey-fy-1998-part-1-operations-workforce.json ... success! File size 315212 bytes
# Downloading https://data.imls.gov/api/views/ne6m-kay3/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1998-part-1-operations-workforce/state-libraries-survey-fy-1998-part-1-operations-workforce.xml ... success! File size 230029 bytes
#
# Found result title: State Libraries Survey, FY 1998, Part 2: SLAA-Provided Services
# Created directory: data/imls/state-libraries-survey-fy-1998-part-2-slaa-provided-services/
# Downloading data.json ... success! file size 1978 bytes
# Downloading https://data.imls.gov/api/views/t328-kigb/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1998-part-2-slaa-provided-services/state-libraries-survey-fy-1998-part-2-slaa-provided-services.csv ... success! File size 24576 bytes
# Downloading https://data.imls.gov/api/views/t328-kigb/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1998-part-2-slaa-provided-services/state-libraries-survey-fy-1998-part-2-slaa-provided-services.rdf ... success! File size 220436 bytes
# Downloading https://data.imls.gov/api/views/t328-kigb/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1998-part-2-slaa-provided-services/state-libraries-survey-fy-1998-part-2-slaa-provided-services.json ... success! File size 126999 bytes
# Downloading https://data.imls.gov/api/views/t328-kigb/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1998-part-2-slaa-provided-services/state-libraries-survey-fy-1998-part-2-slaa-provided-services.xml ... success! File size 147280 bytes
#
# Found result title: State Libraries Survey, FY 1995, Part 2: SLAA-Provided Services
# Created directory: data/imls/state-libraries-survey-fy-1995-part-2-slaa-provided-services/
# Downloading data.json ... success! file size 1978 bytes
# Downloading https://data.imls.gov/api/views/hk4d-dib5/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1995-part-2-slaa-provided-services/state-libraries-survey-fy-1995-part-2-slaa-provided-services.csv ... success! File size 22675 bytes
# Downloading https://data.imls.gov/api/views/hk4d-dib5/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1995-part-2-slaa-provided-services/state-libraries-survey-fy-1995-part-2-slaa-provided-services.rdf ... success! File size 209230 bytes
# Downloading https://data.imls.gov/api/views/hk4d-dib5/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1995-part-2-slaa-provided-services/state-libraries-survey-fy-1995-part-2-slaa-provided-services.json ... success! File size 119693 bytes
# Downloading https://data.imls.gov/api/views/hk4d-dib5/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1995-part-2-slaa-provided-services/state-libraries-survey-fy-1995-part-2-slaa-provided-services.xml ... success! File size 139462 bytes
#
# Found result title: State Libraries Survey, FY 2014, Part 1: Operations & Workforce
# Created directory: data/imls/state-libraries-survey-fy-2014-part-1-operations-workforce/
# Downloading data.json ... success! file size 1979 bytes
# Downloading https://data.imls.gov/api/views/ega2-r6pd/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2014-part-1-operations-workforce/state-libraries-survey-fy-2014-part-1-operations-workforce.csv ... success! File size 30525 bytes
# Downloading https://data.imls.gov/api/views/ega2-r6pd/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2014-part-1-operations-workforce/state-libraries-survey-fy-2014-part-1-operations-workforce.rdf ... success! File size 236052 bytes
# Downloading https://data.imls.gov/api/views/ega2-r6pd/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2014-part-1-operations-workforce/state-libraries-survey-fy-2014-part-1-operations-workforce.json ... success! File size 182516 bytes
# Downloading https://data.imls.gov/api/views/ega2-r6pd/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2014-part-1-operations-workforce/state-libraries-survey-fy-2014-part-1-operations-workforce.xml ... success! File size 157927 bytes
#
# Found result title: State Libraries Survey, FY 2001, Part 3: Revenue & Expenditures
# Created directory: data/imls/state-libraries-survey-fy-2001-part-3-revenue-expenditures/
# Downloading data.json ... success! file size 1979 bytes
# Downloading https://data.imls.gov/api/views/mem6-3u6k/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2001-part-3-revenue-expenditures/state-libraries-survey-fy-2001-part-3-revenue-expenditures.csv ... success! File size 56952 bytes
# Downloading https://data.imls.gov/api/views/mem6-3u6k/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2001-part-3-revenue-expenditures/state-libraries-survey-fy-2001-part-3-revenue-expenditures.rdf ... success! File size 218577 bytes
# Downloading https://data.imls.gov/api/views/mem6-3u6k/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2001-part-3-revenue-expenditures/state-libraries-survey-fy-2001-part-3-revenue-expenditures.json ... success! File size 217648 bytes
# Downloading https://data.imls.gov/api/views/mem6-3u6k/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2001-part-3-revenue-expenditures/state-libraries-survey-fy-2001-part-3-revenue-expenditures.xml ... success! File size 152948 bytes
#
# Found result title: State Libraries Survey, FY 2000, Part 1: Operations & Workforce
# Created directory: data/imls/state-libraries-survey-fy-2000-part-1-operations-workforce/
# Downloading data.json ... success! file size 1979 bytes
# Downloading https://data.imls.gov/api/views/xa7b-pyuw/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2000-part-1-operations-workforce/state-libraries-survey-fy-2000-part-1-operations-workforce.csv ... success! File size 42322 bytes
# Downloading https://data.imls.gov/api/views/xa7b-pyuw/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2000-part-1-operations-workforce/state-libraries-survey-fy-2000-part-1-operations-workforce.rdf ... success! File size 355126 bytes
# Downloading https://data.imls.gov/api/views/xa7b-pyuw/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2000-part-1-operations-workforce/state-libraries-survey-fy-2000-part-1-operations-workforce.json ... success! File size 322588 bytes
# Downloading https://data.imls.gov/api/views/xa7b-pyuw/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2000-part-1-operations-workforce/state-libraries-survey-fy-2000-part-1-operations-workforce.xml ... success! File size 239983 bytes
#
# Found result title: State Libraries Survey, FY 2008, Part 3: Revenue & Expenditures
# Created directory: data/imls/state-libraries-survey-fy-2008-part-3-revenue-expenditures/
# Downloading data.json ... success! file size 1979 bytes
# Downloading https://data.imls.gov/api/views/t6s9-mm7b/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2008-part-3-revenue-expenditures/state-libraries-survey-fy-2008-part-3-revenue-expenditures.csv ... success! File size 56890 bytes
# Downloading https://data.imls.gov/api/views/t6s9-mm7b/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2008-part-3-revenue-expenditures/state-libraries-survey-fy-2008-part-3-revenue-expenditures.rdf ... success! File size 221523 bytes
# Downloading https://data.imls.gov/api/views/t6s9-mm7b/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2008-part-3-revenue-expenditures/state-libraries-survey-fy-2008-part-3-revenue-expenditures.json ... success! File size 210687 bytes
# Downloading https://data.imls.gov/api/views/t6s9-mm7b/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2008-part-3-revenue-expenditures/state-libraries-survey-fy-2008-part-3-revenue-expenditures.xml ... success! File size 154618 bytes
#
# Found result title: State Libraries Survey, FY 2009, Part 2: SLAA-Provided Services
# Created directory: data/imls/state-libraries-survey-fy-2009-part-2-slaa-provided-services/
# Downloading data.json ... success! file size 1978 bytes
# Downloading https://data.imls.gov/api/views/2cw6-8ifq/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2009-part-2-slaa-provided-services/state-libraries-survey-fy-2009-part-2-slaa-provided-services.csv ... success! File size 25825 bytes
# Downloading https://data.imls.gov/api/views/2cw6-8ifq/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2009-part-2-slaa-provided-services/state-libraries-survey-fy-2009-part-2-slaa-provided-services.rdf ... success! File size 239233 bytes
# Downloading https://data.imls.gov/api/views/2cw6-8ifq/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2009-part-2-slaa-provided-services/state-libraries-survey-fy-2009-part-2-slaa-provided-services.json ... success! File size 141513 bytes
# Downloading https://data.imls.gov/api/views/2cw6-8ifq/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2009-part-2-slaa-provided-services/state-libraries-survey-fy-2009-part-2-slaa-provided-services.xml ... success! File size 159271 bytes
#
# Found result title: State Libraries Survey, FY 2014, Part 2: SLAA-Provided Services
# Created directory: data/imls/state-libraries-survey-fy-2014-part-2-slaa-provided-services/
# Downloading data.json ... success! file size 1978 bytes
# Downloading https://data.imls.gov/api/views/qgbd-i4n4/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2014-part-2-slaa-provided-services/state-libraries-survey-fy-2014-part-2-slaa-provided-services.csv ... success! File size 32613 bytes
# Downloading https://data.imls.gov/api/views/qgbd-i4n4/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2014-part-2-slaa-provided-services/state-libraries-survey-fy-2014-part-2-slaa-provided-services.rdf ... success! File size 322143 bytes
# Downloading https://data.imls.gov/api/views/qgbd-i4n4/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2014-part-2-slaa-provided-services/state-libraries-survey-fy-2014-part-2-slaa-provided-services.json ... success! File size 180299 bytes
# Downloading https://data.imls.gov/api/views/qgbd-i4n4/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2014-part-2-slaa-provided-services/state-libraries-survey-fy-2014-part-2-slaa-provided-services.xml ... success! File size 221017 bytes
#
# Found result title: IMLS Appropriations (FY 2002-2017)
# Created directory: data/imls/imls-appropriations-fy-2002-2017/
# Downloading data.json ... success! file size 1418 bytes
# Downloading https://data.imls.gov/api/views/pv6v-66cr/rows.csv?accessType=DOWNLOAD as data/imls/imls-appropriations-fy-2002-2017/imls-appropriations-fy-2002-2017.csv ... success! File size 3495 bytes
# Downloading https://data.imls.gov/api/views/pv6v-66cr/rows.rdf?accessType=DOWNLOAD as data/imls/imls-appropriations-fy-2002-2017/imls-appropriations-fy-2002-2017.rdf ... success! File size 15944 bytes
# Downloading https://data.imls.gov/api/views/pv6v-66cr/rows.json?accessType=DOWNLOAD as data/imls/imls-appropriations-fy-2002-2017/imls-appropriations-fy-2002-2017.json ... success! File size 41260 bytes
# Downloading https://data.imls.gov/api/views/pv6v-66cr/rows.xml?accessType=DOWNLOAD as data/imls/imls-appropriations-fy-2002-2017/imls-appropriations-fy-2002-2017.xml ... success! File size 10782 bytes
#
# Found result title: State Libraries Survey, FY 2006, Part 3: Revenue & Expenditures
# Created directory: data/imls/state-libraries-survey-fy-2006-part-3-revenue-expenditures/
# Downloading data.json ... success! file size 1979 bytes
# Downloading https://data.imls.gov/api/views/4yk9-qksv/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2006-part-3-revenue-expenditures/state-libraries-survey-fy-2006-part-3-revenue-expenditures.csv ... success! File size 56466 bytes
# Downloading https://data.imls.gov/api/views/4yk9-qksv/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2006-part-3-revenue-expenditures/state-libraries-survey-fy-2006-part-3-revenue-expenditures.rdf ... success! File size 221292 bytes
# Downloading https://data.imls.gov/api/views/4yk9-qksv/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2006-part-3-revenue-expenditures/state-libraries-survey-fy-2006-part-3-revenue-expenditures.json ... success! File size 212544 bytes
# Downloading https://data.imls.gov/api/views/4yk9-qksv/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-2006-part-3-revenue-expenditures/state-libraries-survey-fy-2006-part-3-revenue-expenditures.xml ... success! File size 154233 bytes
#
# Found result title: State Libraries Survey, FY 1995, Part 1: Operations & Workforce
# Created directory: data/imls/state-libraries-survey-fy-1995-part-1-operations-workforce/
# Downloading data.json ... success! file size 1979 bytes
# Downloading https://data.imls.gov/api/views/fixd-rw4z/rows.csv?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1995-part-1-operations-workforce/state-libraries-survey-fy-1995-part-1-operations-workforce.csv ... success! File size 39753 bytes
# Downloading https://data.imls.gov/api/views/fixd-rw4z/rows.rdf?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1995-part-1-operations-workforce/state-libraries-survey-fy-1995-part-1-operations-workforce.rdf ... success! File size 323052 bytes
# Downloading https://data.imls.gov/api/views/fixd-rw4z/rows.json?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1995-part-1-operations-workforce/state-libraries-survey-fy-1995-part-1-operations-workforce.json ... success! File size 299105 bytes
# Downloading https://data.imls.gov/api/views/fixd-rw4z/rows.xml?accessType=DOWNLOAD as data/imls/state-libraries-survey-fy-1995-part-1-operations-workforce/state-libraries-survey-fy-1995-part-1-operations-workforce.xml ... success! File size 216270 bytes
#
# Script ended at 20170418-215146

# %%
file_log.close()
